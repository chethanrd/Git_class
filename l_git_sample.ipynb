# %%
a=2
b=2
print(a is b)  # Output: True
# Out:
# True

# %%
c=3
d=6
print(c*d)  # Output: 18
# Out:
# 18

# %%
a="Hello"
b="Hello"

print(a is b)  # Output: True
# Out:
# True

# %%
c="Hello Chethan"
d="Hello chethan!" 
print(c is d)  # Output: False
# Out:
# False

# %%
import sys

# %%
e=sys.intern("Hello Chethan")
f=sys.intern("Hello Chethan")
print(e is f)  # Output: True
# Out:
# True

# %%
print(e,id(e))
# Out:
# Hello Chethan 2498606021296
