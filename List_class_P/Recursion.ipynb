# %%
a=1

# %%
# Recursion 
# 1. Base case 
# 2. Changing the state and move towards the base case
# 3. It should call itself recursively

# %%
#winding  and unwinding

# %%
def my_fact(num):
    if num==1:
        return 1
    else:
        return num* my_fact(num-1)

my_fact(4)
# Out:
# 24

# %%
#Iterator, Iterable

#sequence -string,list,tuple,bytes,bytearray
#iterable- Object which implements the iter function 
# string,list,tuple,dictionary,set,frozenset,range,filter,map,zip,enumearate

#iterator- object which implements the iter and next function
 #filter,map,zip,enumerate

#we can get the value inorder to get the value will be call next funcation.
# iterator not creatig all the values at a time..
#lazy evaluation - evrytime we call the next function then iterator evaluates and returns the value
#memory eficient , optimizing memory.
#

# %%
#realising the values from iterator
# -> using list function, tuple, string methods......

# %%
#Generator - using Tuple comprehension
#using function definition syntax
