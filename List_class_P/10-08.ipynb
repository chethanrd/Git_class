# %%
Identifiers
name,address,type of account, gender, documentation
banking operation
addding the money,subtraction of money when withdraw, percentage of intrest, charges for bank services.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 Identifiers
#
# NameError: name 'Identifiers' is not defined

# %%
principal=100000
rate=7
time=3
print(principal+(7*3*principal)/100)
# Out:
# 121000.0

# %%
note_500=100
note_200=50
note_100=45
note_50=30
print("Total amount deposited:",(note_500*500)+(note_200*200)+(note_100*100)+(note_50*50))
# Out:
# Total amount deposited: 66000

# %%
loan_dist=1000000
intrest_rec=95000
operational_cost=15000

profit=intrest_rec-operational_cost
profit
# Out:
# 80000
