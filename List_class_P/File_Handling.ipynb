# %%
#modules in python

import math
import numpy as np

# %%
def my_add(a,b):
    return a+b

lst=[1,2,3,4,5,6,7,8,9]

# %%
def is_even(num):
    return True if num%2==0 else False

# %%
def my_filter(func,seq):
    out_lst=[]
    for ele in seq:
        if func(ele)==True:
            out_lst.append(ele)
    return out_lst

# %%
my_filter(is_even,lst)
# Out:
# [2, 4, 6, 8]

# %%
# file handling python 

# text file
#binary file 

#Reading , writing and appending into the file.

# %%
# open the file -open('file_name.ext','mode')
# returns file object which can be stored in the variable 
# closing the file at the end is mandatory
f=open('my_mode.py','r')
print(f.read())
f.close()
# Out:
# #modules in python
#
# import math
#
#
# def my_add(a,b):
#     return a+b
#
# lst=[1,2,3,4,5,6,7,8,9]
#
# def is_even(num):
#     return True if num%2==0 else False
#
# def my_filter(func,seq):
#     out_lst=[]
#     for ele in seq:
#         if func(ele)==True:
#             out_lst.append(ele)
#     return out_lst
#
# print(__name__,type(__name__))
#
# def main():
#    print(my_filter(is_even,lst))
#
# if __name__=="__main__":
#     main()
#
#
#
# # when we execute the module directly, then __main__ is set to __main__
# # when we import the module directly, then __name__ is set to __module_name__

# %%
# diffrent mode of operation in python text file handling operation

Read mode - 'r'
Write mode- 'w'
Append mode -'a'
Read and write mode -'r+'
write and read mode -'w+'
append and read mode -'a+'

# %%
# diffrent mode of operation in python Binary file  operation

Read mode - 'rb'
Write mode- 'wb'
Append mode -'ab'
Read and write mode -'r+b'
write and read mode -'w+b'
append and read mode -'a+b'

# %%
# method 
#f.read()-> read the whole content of the file from current cursor position and return a string object
#f.read(10)-> read the specified no of characters from current cursor position and returns a string object 
# f.readline()-> reads the current line from current cursor position and returns a string object.
#f.readline(10) > Read the specified no of lines from current cursor position and returns a string object
#f.readlines() ->

# %%
# f.write('string')-> writes the string to the file from current cursor position onwards
# f.writelines(['str1\n','str2','str3'...])-> writes the eacg string as  new line into the file.

# %%
#f.tell()-> gives you current cursor position.
#f.seek(pso) -> used to move around the file in diffrent cursor.

# %%
f=open('my_mode.py','r')
print("current cursor position before reading",f.tell())
#print(f.read())
#print(f.readline(100))
#print(f.readlines()) -> read the eny=tire file returns in the list of each lines.
print(f.read(50))
print("current cursor position after reading",f.tell())
f.close()
# Out:
# current cursor position before reading 0
# #modules in python
#
# import math
#
#
# def my_add(a,b):
# current cursor position after reading 55

# %%
#read mode -'r'
#1. if file ecist it oprns the file in read mode and cursor will be at the beggining of the file
#if the file does not exist then it raises filenotfounderror,
#in this mode, you are allowed only to read but not allowed to erite into file 

f=open('my_mode.py','r')
print('current cursor position is',f.tell())
print(f.read())
print("Curent cusror position after reading", f.tell())
f.close()
# Out:
# current cursor position is 0
# #modules in python
#
# import math
#
#
# def my_add(a,b):
#     return a+b
#
# lst=[1,2,3,4,5,6,7,8,9]
#
# def is_even(num):
#     return True if num%2==0 else False
#
# def my_filter(func,seq):
#     out_lst=[]
#     for ele in seq:
#         if func(ele)==True:
#             out_lst.append(ele)
#     return out_lst
#
# print(__name__,type(__name__))
#
# def main():
#    print(my_filter(is_even,lst))
#
# if __name__=="__main__":
#     main()
#
#
#
# # when we execute the module directly, then __main__ is set to __main__
# # when we import the module directly, then __name__ is set to __module_name__
# Curent cusror position after reading 587

# %%
f=open('my_mode.py','r')
f.write('Hello')
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[28], line 2
#       1 f=open('my_mode.py','r')
# ----> 2 f.write('Hello')
#
# UnsupportedOperation: not writable

# %%
#Read and write mode 'r+

# it allowed to read and write.
#in read and write mode replacces the charcter from current cursor postion. 

f=open('my_mode.py','r+')
f.write("Hello")
f.close()

# %%
# write mode
# if trhe file exists, then it will first delete the content of the file after opening in the wroite mode 
# if this file does't exist it will create a file with jgiven bname and extension
#in this mode, you are allowed inly to write content 

f=open('my_mode1.py','w')
print("current cursor position after opening the file",f.tell())
print(f.write("Hello python file handling class"))
f.close()
# Out:
# current cursor position after opening the file 0
# 32

# %%
f=open('my_mode2.py','w')
f.close()

# %%
#append mode 'a'
f=open('my_mode1.py','a')
print("current cursor position after opening the file",f.tell())
f.write('\n Hello')
f.close()
# Out:
# current cursor position after opening the file 32

# %%
# with statement
# it closes the file automaticlaly when declare with with

with open('my_mode.py','r') as f:
    print(f.read())
# Out:
# Helloles in python
#
# import math
#
#
# def my_add(a,b):
#     return a+b
#
# lst=[1,2,3,4,5,6,7,8,9]
#
# def is_even(num):
#     return True if num%2==0 else False
#
# def my_filter(func,seq):
#     out_lst=[]
#     for ele in seq:
#         if func(ele)==True:
#             out_lst.append(ele)
#     return out_lst
#
# print(__name__,type(__name__))
#
# def main():
#    print(my_filter(is_even,lst))
#
# if __name__=="__main__":
#     main()
#
#
#
# # when we execute the module directly, then __main__ is set to __main__
# # when we import the module directly, then __name__ is set to __module_name__

# %%
with open('my_mode.py','r+') as f :
    f.write("This is write plus read mode")
    print(f.read())
# Out:
#  math
#
#
# def my_add(a,b):
#     return a+b
#
# lst=[1,2,3,4,5,6,7,8,9]
#
# def is_even(num):
#     return True if num%2==0 else False
#
# def my_filter(func,seq):
#     out_lst=[]
#     for ele in seq:
#         if func(ele)==True:
#             out_lst.append(ele)
#     return out_lst
#
# print(__name__,type(__name__))
#
# def main():
#    print(my_filter(is_even,lst))
#
# if __name__=="__main__":
#     main()
#
#
#
# # when we execute the module directly, then __main__ is set to __main__
# # when we import the module directly, then __name__ is set to __module_name__

# %%
with open ("fil1.txt",'w+') as f:
    print("Before adding phrase in a new sentence in the file:",f.tell())
    f.write("This is the 1st phrase of wrting in new file")
    print("After adding phrase in a new sentence in the file:",f.tell())
    print(f.read())
# Out:
# Before adding phrase in a new sentence in the file: 0
# After adding phrase in a new sentence in the file: 44

# %%
with open('fil1.txt','a') as f:
    f.write("/n Line 2: Adding second line.\n")
    
with open('fil1.txt','r') as f:
    print(f.read())
# Out:
# This is the 1st phrase of wrting in new fileLine 2: Adding second line.
# Line 3: Adding third line.
# Line 3: Adding third line.
# Line 3: Adding third line.
# Line 2: Adding second line.
# /n Line 2: Adding second line.

# %%
with open("fil1.txt",'a') as f:
    f.write("Line 3: Adding third line.\n")

with open("fil1.txt",'r') as f:
    print(f.read())
# Out:
# This is the 1st phrase of wrting in new fileLine 2: Adding second line.
# Line 3: Adding third line.
# Line 3: Adding third line.
# Line 3: Adding third line.

# %%
with open("fil1.txt",'w') as f:
    f.write("Adding the new sentence to replace of all line")

with open("fil1.txt",'r') as f:
    print(f.read())
# Out:
# Adding the new sentence to replace of all line

# %%
with open("fil1.txt",'a') as f:
    f.write(" Extensio of adding to the same file.\n")
    f.write("Line 2: Adding second line.\n")
    f.write("Line 3: Adding Third line.\n")
    f.write("Line 4: Adding Fourth line.\n")

with open("fil1.txt",'r') as f:
    print(f.read())
# Out:
# Adding the new sentence to replace of all line Extensio of adding to the same file.
# Line 2: Adding second line.
# Line 3: Adding Third line.
# Line 4: Adding Fourth line.

# %%
with open('fil1.txt','r') as f:
    print(f.readline())
    print(f.readline())
# Out:
# Adding the new sentence to replace of all line Extensio of adding to the same file.
#
# Line 2: Adding second line.

# %%
with open('fil1.txt','r') as f:
    print(f.readlines())
# Out:
# ['Adding the new sentence to replace of all line Extensio of adding to the same file.\n', 'Line 2: Adding second line.\n', 'Line 3: Adding Third line.\n', 'Line 4: Adding Fourth line.\n']

# %%
with open('fil1.txt','r') as f:
    content=f.read()

lines=content.splitlines()
word=content.split()

print("Lines:",len(lines))
print("words:",len(word))
print("characters:",len(content))
# Out:
# Lines: 4
# words: 31
# characters: 167
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 10
#       8 print("words:",len(word))
#       9 print("characters:",len(content))
# ---> 10 print("After Reading the lines cursor at the position of:",f.tell())
#
# ValueError: I/O operation on closed file.

# %%
with open('fil1.txt','r') as f:
    print(f.tell())
    print(f.read(5))
    print(f.seek(0))
# Out:
# 0
# Addin
# 0

# %%
with open("fil1.txt",'r') as f:
    content=f.read()

    lines=content.splitlines()
    print(lines)
    print("after reading the file cursor at the position of:",f.tell())
    position=sum(len(line) for line in lines[:1])
    print(position)
    print("Moving the cursor at the fist sentence that is:",f.tell())
    print(f.seek(position))
# Out:
# ['Adding the new sentence to replace of all line Extensio of adding to the same file.', 'Line 2: Adding second line.', 'Line 3: Adding Third line.', 'Line 4: Adding Fourth line.']
# after reading the file cursor at the position of: 171
# 83
# Moving the cursor at the fist sentence that is: 171
# 83

# %%
import os

if not os.path.exists('File2.txt'):
    with open("File2.txt",'w') as f:
        f.write("Creating new file it is not created")
    print("File created")
else:
    print("File Already exists.")
# Out:
# File created

# %%
if not os.path.exists("File2.txt"):
    with open("File2.txt",'w') as f:
        f.write("creating new file")
    print("File created")
else:
    print("File already exist")
# Out:
# File already exist

# %%
from collections import Counter

# %%
with open("fil1.txt",'r') as f:
    content=f.read().lower()

words=content.split()
word_counts=Counter(words)

print(word_counts)

for word, count in word_counts.most_common(5):
    print(word,":",count)
# Out:
# Counter({'adding': 5, 'line': 4, 'line.': 3, 'the': 2, 'to': 2, 'of': 2, 'new': 1, 'sentence': 1, 'replace': 1, 'all': 1, 'extensio': 1, 'same': 1, 'file.': 1, '2:': 1, 'second': 1, '3:': 1, 'third': 1, '4:': 1, 'fourth': 1})
# adding : 5
# line : 4
# line. : 3
# the : 2
# to : 2

# %%
print(dir(Counter))
# Out:
# ['__add__', '__and__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__iand__', '__init__', '__init_subclass__', '__ior__', '__isub__', '__iter__', '__le__', '__len__', '__lt__', '__missing__', '__module__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__weakref__', '_keep_positive', 'clear', 'copy', 'elements', 'fromkeys', 'get', 'items', 'keys', 'most_common', 'pop', 'popitem', 'setdefault', 'subtract', 'total', 'update', 'values']

# %%
import numpy as np

# %%
def copy_file(source,destination):
    with open(source,'r') as src:
        content=src.read()

    with open(destination,'w') as dest:
        dest.write(content)
copy_file('File1.txt','File3.txt')
