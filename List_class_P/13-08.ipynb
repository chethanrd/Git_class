# %%
data=[1200,5000,25000,75,15000,25,150,150000,15000000]
for i in data:
    if i>100 and i<100000:
        print("Transaction valid",i)
    else:
        print("Transaction not valid",i)
# Out:
# Transaction valid 1200
# Transaction valid 5000
# Transaction valid 25000
# Transaction not valid 75
# Transaction valid 15000
# Transaction not valid 25
# Transaction valid 150
# Transaction not valid 150000
# Transaction not valid 15000000
