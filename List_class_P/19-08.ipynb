# %%
print(dir(set))
print(dir(dict))
# Out:
# ['__and__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__iand__', '__init__', '__init_subclass__', '__ior__', '__isub__', '__iter__', '__ixor__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__rand__', '__reduce__', '__reduce_ex__', '__repr__', '__ror__', '__rsub__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__xor__', 'add', 'clear', 'copy', 'difference', 'difference_update', 'discard', 'intersection', 'intersection_update', 'isdisjoint', 'issubset', 'issuperset', 'pop', 'remove', 'symmetric_difference', 'symmetric_difference_update', 'union', 'update']
# ...

# %%
print(help(dict.items))
# Out:
# Help on method_descriptor:
#
# items(...)
#     D.items() -> a set-like object providing a view on D's items
#
# None

# %%
dict_new={"Name":"Chethan", "id":101,"Gender":"Male"}

# %%
print(type(dict_new.items()))
# Out:
# <class 'dict_items'>

# %%
for key,values in dict_new.items():
    print(key)
    #print(type(key))
   # dict_new[key]="Mic"
# Out:
# Name
# <class 'str'>
# id
# <class 'str'>
# Gender
# <class 'str'>

# %%
dict_new
# Out:
# {'Name': 'Mic', 'id': 'Mic', 'Gender': 'Mic'}

# %%
print(dir(list))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
list1=[["txnon1",23,"credit"],["tx902",24,"debit"]]

# %%
transactions = [
    ["TXN001", "ACC101", "CREDIT", 50000, "SUCCESS"],
    ["TXN002", "ACC101", "DEBIT", 12000, "SUCCESS"],
    ["TXN003", "ACC101", "DEBIT", 5000, "FAILED"],
    ["TXN004", "ACC102", "CREDIT", 75000, "SUCCESS"],
    ["TXN005", "ACC101", "DEBIT", 18000, "SUCCESS"],
    ["TXN006", "ACC102", "DEBIT", 25000, "SUCCESS"],
    ["TXN007", "ACC101", "CREDIT", 10000, "SUCCESS"],
    ["TXN008", "ACC103", "DEBIT", 7000, "SUCCESS"],
    ["TXN009", "ACC101", "DEBIT", 30000, "SUCCESS"],
    ["TXN010", "ACC101", "CREDIT", 20000, "FAILED"]
]

# %%
result=[]
for i in transactions:
    for j in i:
        if j=="ACC101":
            result.append(i)

# %%
result
# Out:
# [['TXN001', 'ACC101', 'CREDIT', 50000, 'SUCCESS'],
#  ['TXN002', 'ACC101', 'DEBIT', 12000, 'SUCCESS'],
#  ['TXN003', 'ACC101', 'DEBIT', 5000, 'FAILED'],
#  ['TXN005', 'ACC101', 'DEBIT', 18000, 'SUCCESS'],
#  ['TXN007', 'ACC101', 'CREDIT', 10000, 'SUCCESS'],
#  ['TXN009', 'ACC101', 'DEBIT', 30000, 'SUCCESS'],
#  ['TXN010', 'ACC101', 'CREDIT', 20000, 'FAILED']]

# %%
sucess_trans=[]
for i in transactions:
    for j in i:
        if j=='SUCCESS':
            sucess_trans.append(i)

# %%
sucess_trans
# Out:
# [['TXN001', 'ACC101', 'CREDIT', 50000, 'SUCCESS'],
#  ['TXN002', 'ACC101', 'DEBIT', 12000, 'SUCCESS'],
#  ['TXN004', 'ACC102', 'CREDIT', 75000, 'SUCCESS'],
#  ['TXN005', 'ACC101', 'DEBIT', 18000, 'SUCCESS'],
#  ['TXN006', 'ACC102', 'DEBIT', 25000, 'SUCCESS'],
#  ['TXN007', 'ACC101', 'CREDIT', 10000, 'SUCCESS'],
#  ['TXN008', 'ACC103', 'DEBIT', 7000, 'SUCCESS'],
#  ['TXN009', 'ACC101', 'DEBIT', 30000, 'SUCCESS']]

# %%
Savings_account_customers=['C101', 'C102', 'C103', 'C104']

Credit_account_customers=['C103', 'C104', 'C105']

Account_Balance ={
    'C101': 50000,
    'C102': 45000,
    'C103': 30000,
    'C104': 20000,
    'C105': 15000
}
Transaction=[
    ('C101', -5000),
    ('C103', 10000),
    ('C104', -2000),
    ('C105', -3000)
]

# %%
unique=list(set(Savings_account_customers+Credit_account_customers))
unique
# Out:
# ['C102', 'C103', 'C101', 'C105', 'C104']

# %%
for account,value in Account_Balance.items():
    print(f"{account}---> Balance: {value}")
# Out:
# C101---> Balance: 50000
# C102---> Balance: 45000
# C103---> Balance: 30000
# C104---> Balance: 20000
# C105---> Balance: 15000

# %%
transaction1=["success","failed","success"]
newq_dic={}
for status in transaction1:
    newq_dic[status]=transaction1.count(status)

# %%
newq_dic
# Out:
# {'success': 2, 'failed': 1}

# %%
print(help(dict.get))
# Out:
# Help on method_descriptor:
#
# get(self, key, default=None, /)
#     Return the value for key if key is in the dictionary, else default.
#
# None
