# %%
Age=int(input("Enter you are age to check eliigibility"))
Month_salary=int(input("Enter you are Monthly Salary to check eliigibility"))
Credit_score=int(input("Enter you are credit score to check eliigibility"))
customer_name=(input("Enter you are Name"))

if Age>21 and Month_salary>30000:
    print(f"{customer_name} is eligible for the loan")

else: 
    if Credit_score<700:
        print(f"{customer_name} is not eligible for the loan")
# Out:
# chethan is not eligible for the loan

# %%
num=int(input('Enter the number'))
if num%2==0:
    print(f"{num} is an even")

else:
      print(f"{num} is an odd")
# Out:
# 9 is an odd

# %%
Age=22
Month_salary=35000

if Age>21 and Month_salary>30000:
    print(f"{customer_name} is eligible for the loan")
# Out:
# chethan is eligible for the loan

# %%
salry=int(input("Enter Salary"))
performance_rating=(int(input("Enter Performance Rating")))
Revised_salry=0

if performance_rating==5:
    Revised_salry=salry+(salry*0.2)
    print(Revised_salry)

elif performance_rating==4:
    Revised_salry=salry+(salry*0.15)
    print(Revised_salry)

elif performance_rating==3:
    Revised_salry=salry+(salry*0.1)
    print(Revised_salry)

else:
     Revised_salry=salry+(salry*0.0)
     print(Revised_salry)
# Out:
# 60000.0

# %%
score=int(input("Enter the student score"))

if score >=0 and score<=100:

    if score>90:
        print(f"student scorre more than 90 Grade A")

    elif score>75:
        print(f"student scorre more than 75 Grade B")

    elif score>65:
        print(f"student scorre more than 65 Grade C")

    else:
        print("Student obtain Grade D")

else:
    print("Invalid score")
# Out:
# student scorre more than 75 Grade B
